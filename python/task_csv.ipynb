# %%
import csv

table = []

# %%
with open('temp/task19.csv', 'r') as file:
    reader = csv.DictReader(file, delimiter=';')
    for row in reader:
        table.append(row)
table
# Out:
# [{'Дата': '1 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '432',
#   'Расход бензина': '63',
#   'Масса груза': '770'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '121',
#   'Расход бензина': '17',
#   'Масса груза': '670'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '333',
#   'Расход бензина': '47',
#   'Масса груза': '830'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '384',
#   'Расход бензина': '54',
#   'Масса груза': '730'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '135',
#   'Расход бензина': '19',
#   'Масса груза': '540'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '112',
#   'Расход бензина': '12',
#   'Масса груза': '970'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '328',
#   'Расход бензина': '46',
#   'Масса груза': '850'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '70',
#   'Расход бензина': '10',
#   'Масса груза': '730'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '297',
#   'Расход бензина': '45',
#   'Масса груза': '620'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '254',
#   'Расход бензина': '44',
#   'Масса груза': '930'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '190',
#   'Расход бензина': '24',
#   'Масса груза': '550'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '333',
#   'Расход бензина': '58',
#   'Масса груза': '830'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '158',
#   'Расход бензина': '22',
#   'Масса груза': '960'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '258',
#   'Расход бензина': '45',
#   'Масса груза': '700'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '156',
#   'Расход бензина': '23',
#   'Масса груза': '810'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '141',
#   'Расход бензина': '23',
#   'Масса груза': '660'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '268',
#   'Расход бензина': '30',
#   'Масса груза': '750'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '193',
#   'Расход бензина': '23',
#   'Масса груза': '660'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '335',
#   'Расход бензина': '54',
#   'Масса груза': '780'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '248',
#   'Расход бензина': '36',
#   'Масса груза': '620'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '123',
#   'Расход бензина': '17',
#   'Масса груза': '880'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '373',
#   'Расход бензина': '52',
#   'Масса груза': '720'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '197',
#   'Расход бензина': '26',
#   'Масса груза': '770'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '301',
#   'Расход бензина': '43',
#   'Масса груза': '960'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '393',
#   'Расход бензина': '47',
#   'Масса груза': '940'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '360',
#   'Расход бензина': '48',
#   'Масса груза': '850'},
#  {'Дата': '1 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '329',
#   'Расход бензина': '51',
#   'Масса груза': '980'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '192',
#   'Расход бензина': '26',
#   'Масса груза': '510'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '189',
#   'Расход бензина': '26',
#   'Масса груза': '840'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '189',
#   'Расход бензина': '30',
#   'Масса груза': '720'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '307',
#   'Расход бензина': '31',
#   'Масса груза': '880'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '332',
#   'Расход бензина': '46',
#   'Масса груза': '650'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '173',
#   'Расход бензина': '24',
#   'Масса груза': '860'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '302',
#   'Расход бензина': '48',
#   'Масса груза': '680'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '136',
#   'Расход бензина': '20',
#   'Масса груза': '600'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '438',
#   'Расход бензина': '61',
#   'Масса груза': '690'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '307',
#   'Расход бензина': '43',
#   'Масса груза': '580'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '381',
#   'Расход бензина': '54',
#   'Масса груза': '520'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '71',
#   'Расход бензина': '11',
#   'Масса груза': '930'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '70',
#   'Расход бензина': '10',
#   'Масса груза': '520'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '191',
#   'Расход бензина': '25',
#   'Масса груза': '960'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '242',
#   'Расход бензина': '29',
#   'Масса груза': '770'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '333',
#   'Расход бензина': '54',
#   'Масса груза': '790'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '187',
#   'Расход бензина': '26',
#   'Масса груза': '590'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '427',
#   'Расход бензина': '58',
#   'Масса груза': '650'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '70',
#   'Расход бензина': '11',
#   'Масса груза': '880'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '122',
#   'Расход бензина': '14',
#   'Масса груза': '990'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '182',
#   'Расход бензина': '26',
#   'Масса груза': '910'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '386',
#   'Расход бензина': '57',
#   'Масса груза': '700'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '391',
#   'Расход бензина': '65',
#   'Масса груза': '570'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '192',
#   'Расход бензина': '27',
#   'Масса груза': '880'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '173',
#   'Расход бензина': '29',
#   'Масса груза': '950'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '165',
#   'Расход бензина': '25',
#   'Масса груза': '770'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '113',
#   'Расход бензина': '18',
#   'Масса груза': '840'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '390',
#   'Расход бензина': '49',
#   'Масса груза': '800'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '330',
#   'Расход бензина': '47',
#   'Масса груза': '950'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '439',
#   'Расход бензина': '72',
#   'Масса груза': '570'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '229',
#   'Расход бензина': '41',
#   'Масса груза': '690'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '253',
#   'Расход бензина': '39',
#   'Масса груза': '630'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '235',
#   'Расход бензина': '33',
#   'Масса груза': '910'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '157',
#   'Расход бензина': '20',
#   'Масса груза': '520'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '133',
#   'Расход бензина': '19',
#   'Масса груза': '680'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '191',
#   'Расход бензина': '27',
#   'Масса груза': '950'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '70',
#   'Расход бензина': '10',
#   'Масса груза': '530'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '337',
#   'Расход бензина': '47',
#   'Масса груза': '960'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '325',
#   'Расход бензина': '45',
#   'Масса груза': '910'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '338',
#   'Расход бензина': '43',
#   'Масса груза': '930'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '387',
#   'Расход бензина': '64',
#   'Масса груза': '680'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '144',
#   'Расход бензина': '24',
#   'Масса груза': '840'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '142',
#   'Расход бензина': '19',
#   'Масса груза': '930'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '424',
#   'Расход бензина': '63',
#   'Масса груза': '910'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '184',
#   'Расход бензина': '26',
#   'Масса груза': '710'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '187',
#   'Расход бензина': '26',
#   'Масса груза': '780'},
#  {'Дата': '2 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '291',
#   'Расход бензина': '33',
#   'Масса груза': '720'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '165',
#   'Расход бензина': '25',
#   'Масса груза': '650'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '159',
#   'Расход бензина': '22',
#   'Масса груза': '760'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '379',
#   'Расход бензина': '53',
#   'Масса груза': '840'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '335',
#   'Расход бензина': '49',
#   'Масса груза': '870'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '184',
#   'Расход бензина': '27',
#   'Масса груза': '860'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '424',
#   'Расход бензина': '59',
#   'Масса груза': '730'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '325',
#   'Расход бензина': '52',
#   'Масса груза': '960'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '182',
#   'Расход бензина': '26',
#   'Масса груза': '860'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '385',
#   'Расход бензина': '54',
#   'Масса груза': '910'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '308',
#   'Расход бензина': '37',
#   'Масса груза': '730'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '265',
#   'Расход бензина': '38',
#   'Масса груза': '940'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '310',
#   'Расход бензина': '43',
#   'Масса груза': '710'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '258',
#   'Расход бензина': '36',
#   'Масса груза': '840'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '142',
#   'Расход бензина': '15',
#   'Масса груза': '580'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '233',
#   'Расход бензина': '33',
#   'Масса груза': '750'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '187',
#   'Расход бензина': '34',
#   'Масса груза': '990'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '297',
#   'Расход бензина': '41',
#   'Масса груза': '620'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '259',
#   'Расход бензина': '34',
#   'Масса груза': '630'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '184',
#   'Расход бензина': '26',
#   'Масса груза': '800'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '71',
#   'Расход бензина': '10',
#   'Масса груза': '730'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '243',
#   'Расход бензина': '32',
#   'Масса груза': '690'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '309',
#   'Расход бензина': '43',
#   'Масса груза': '640'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '292',
#   'Расход бензина': '41',
#   'Масса груза': '750'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '384',
#   'Расход бензина': '51',
#   'Масса груза': '920'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '196',
#   'Расход бензина': '27',
#   'Масса груза': '830'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '157',
#   'Расход бензина': '22',
#   'Масса груза': '840'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '113',
#   'Расход бензина': '16',
#   'Масса груза': '570'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '175',
#   'Расход бензина': '24',
#   'Масса груза': '550'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '145',
#   'Расход бензина': '20',
#   'Масса груза': '820'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '307',
#   'Расход бензина': '37',
#   'Масса груза': '890'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '135',
#   'Расход бензина': '19',
#   'Масса груза': '910'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '332',
#   'Расход бензина': '47',
#   'Масса груза': '880'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '190',
#   'Расход бензина': '31',
#   'Масса груза': '930'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '159',
#   'Расход бензина': '18',
#   'Масса груза': '570'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '188',
#   'Расход бензина': '30',
#   'Масса груза': '980'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '293',
#   'Расход бензина': '40',
#   'Масса груза': '920'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '159',
#   'Расход бензина': '22',
#   'Масса груза': '800'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '268',
#   'Расход бензина': '33',
#   'Масса груза': '650'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '310',
#   'Расход бензина': '43',
#   'Масса груза': '640'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '110',
#   'Расход бензина': '16',
#   'Масса груза': '820'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '338',
#   'Расход бензина': '36',
#   'Масса груза': '620'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '114',
#   'Расход бензина': '20',
#   'Масса груза': '920'},
#  {'Дата': '3 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '230',
#   'Расход бензина': '25',
#   'Масса груза': '660'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '142',
#   'Расход бензина': '20',
#   'Масса груза': '590'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '191',
#   'Расход бензина': '27',
#   'Масса груза': '750'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '187',
#   'Расход бензина': '26',
#   'Масса груза': '890'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '185',
#   'Расход бензина': '26',
#   'Масса груза': '970'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '315',
#   'Расход бензина': '43',
#   'Масса груза': '870'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '227',
#   'Расход бензина': '32',
#   'Масса груза': '710'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '261',
#   'Расход бензина': '36',
#   'Масса груза': '960'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '435',
#   'Расход бензина': '63',
#   'Масса груза': '910'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '132',
#   'Расход бензина': '18',
#   'Масса груза': '760'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '126',
#   'Расход бензина': '18',
#   'Масса груза': '560'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '299',
#   'Расход бензина': '42',
#   'Масса груза': '680'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '185',
#   'Расход бензина': '20',
#   'Масса груза': '770'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '245',
#   'Расход бензина': '35',
#   'Масса груза': '760'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '178',
#   'Расход бензина': '24',
#   'Масса груза': '730'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '132',
#   'Расход бензина': '17',
#   'Масса груза': '920'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '297',
#   'Расход бензина': '43',
#   'Масса груза': '610'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '71',
#   'Расход бензина': '7',
#   'Масса груза': '540'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '294',
#   'Расход бензина': '41',
#   'Масса груза': '850'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '251',
#   'Расход бензина': '35',
#   'Масса груза': '540'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '228',
#   'Расход бензина': '29',
#   'Масса груза': '520'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '140',
#   'Расход бензина': '22',
#   'Масса груза': '870'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '258',
#   'Расход бензина': '37',
#   'Масса груза': '870'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '368',
#   'Расход бензина': '52',
#   'Масса груза': '870'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '227',
#   'Расход бензина': '31',
#   'Масса груза': '610'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '324',
#   'Расход бензина': '32',
#   'Масса груза': '550'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '322',
#   'Расход бензина': '45',
#   'Масса груза': '870'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '377',
#   'Расход бензина': '53',
#   'Масса груза': '550'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '267',
#   'Расход бензина': '37',
#   'Масса груза': '680'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '69',
#   'Расход бензина': '10',
#   'Масса груза': '780'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '175',
#   'Расход бензина': '18',
#   'Масса груза': '670'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '70',
#   'Расход бензина': '13',
#   'Масса груза': '590'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '333',
#   'Расход бензина': '47',
#   'Масса груза': '820'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '308',
#   'Расход бензина': '43',
#   'Масса груза': '500'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '257',
#   'Расход бензина': '41',
#   'Масса груза': '600'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '367',
#   'Расход бензина': '51',
#   'Масса груза': '820'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '118',
#   'Расход бензина': '19',
#   'Масса груза': '560'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '386',
#   'Расход бензина': '53',
#   'Масса груза': '970'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '262',
#   'Расход бензина': '36',
#   'Масса груза': '650'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '396',
#   'Расход бензина': '41',
#   'Масса груза': '840'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '124',
#   'Расход бензина': '18',
#   'Масса груза': '680'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '432',
#   'Расход бензина': '67',
#   'Масса груза': '900'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '112',
#   'Расход бензина': '11',
#   'Масса груза': '740'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '187',
#   'Расход бензина': '26',
#   'Масса груза': '730'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '393',
#   'Расход бензина': '44',
#   'Масса груза': '870'},
#  {'Дата': '4 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '438',
#   'Расход бензина': '54',
#   'Масса груза': '510'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '381',
#   'Расход бензина': '56',
#   'Масса груза': '560'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '330',
#   'Расход бензина': '57',
#   'Масса груза': '830'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '432',
#   'Расход бензина': '66',
#   'Масса груза': '850'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '309',
#   'Расход бензина': '44',
#   'Масса груза': '790'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '341',
#   'Расход бензина': '48',
#   'Масса груза': '930'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '190',
#   'Расход бензина': '27',
#   'Масса груза': '550'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '328',
#   'Расход бензина': '47',
#   'Масса груза': '610'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '185',
#   'Расход бензина': '28',
#   'Масса груза': '830'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '187',
#   'Расход бензина': '31',
#   'Масса груза': '690'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '186',
#   'Расход бензина': '26',
#   'Масса груза': '680'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '113',
#   'Расход бензина': '18',
#   'Масса груза': '840'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '384',
#   'Расход бензина': '54',
#   'Масса груза': '540'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '192',
#   'Расход бензина': '23',
#   'Масса груза': '850'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '162',
#   'Расход бензина': '23',
#   'Масса груза': '720'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '159',
#   'Расход бензина': '20',
#   'Масса груза': '840'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '334',
#   'Расход бензина': '52',
#   'Масса груза': '550'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '244',
#   'Расход бензина': '37',
#   'Масса груза': '710'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '196',
#   'Расход бензина': '27',
#   'Масса груза': '970'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '333',
#   'Расход бензина': '42',
#   'Масса груза': '860'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '392',
#   'Расход бензина': '59',
#   'Масса груза': '730'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '125',
#   'Расход бензина': '19',
#   'Масса груза': '660'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '293',
#   'Расход бензина': '37',
#   'Масса груза': '690'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '195',
#   'Расход бензина': '34',
#   'Масса груза': '700'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '436',
#   'Расход бензина': '55',
#   'Масса груза': '930'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '135',
#   'Расход бензина': '19',
#   'Масса груза': '600'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '179',
#   'Расход бензина': '25',
#   'Масса груза': '830'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '317',
#   'Расход бензина': '46',
#   'Масса груза': '510'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '124',
#   'Расход бензина': '17',
#   'Масса груза': '590'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '360',
#   'Расход бензина': '54',
#   'Масса груза': '620'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '309',
#   'Расход бензина': '53',
#   'Масса груза': '790'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '316',
#   'Расход бензина': '56',
#   'Масса груза': '710'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '245',
#   'Расход бензина': '35',
#   'Масса груза': '750'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '196',
#   'Расход бензина': '27',
#   'Масса груза': '680'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '177',
#   'Расход бензина': '20',
#   'Масса груза': '620'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '253',
#   'Расход бензина': '36',
#   'Масса груза': '780'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '334',
#   'Расход бензина': '44',
#   'Масса груза': '970'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '160',
#   'Расход бензина': '23',
#   'Масса груза': '670'},
#  {'Дата': '5 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '314',
#   'Расход бензина': '37',
#   'Масса груза': '670'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '335',
#   'Расход бензина': '47',
#   'Масса груза': '500'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '245',
#   'Расход бензина': '35',
#   'Масса груза': '910'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '195',
#   'Расход бензина': '35',
#   'Масса груза': '540'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '383',
#   'Расход бензина': '45',
#   'Масса груза': '640'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '160',
#   'Расход бензина': '22',
#   'Масса груза': '870'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '306',
#   'Расход бензина': '44',
#   'Масса груза': '930'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '71',
#   'Расход бензина': '10',
#   'Масса груза': '740'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '261',
#   'Расход бензина': '44',
#   'Масса груза': '840'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '304',
#   'Расход бензина': '42',
#   'Масса груза': '720'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '315',
#   'Расход бензина': '41',
#   'Масса груза': '500'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '183',
#   'Расход бензина': '25',
#   'Масса груза': '820'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '161',
#   'Расход бензина': '22',
#   'Масса груза': '940'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '126',
#   'Расход бензина': '18',
#   'Масса груза': '810'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '257',
#   'Расход бензина': '35',
#   'Масса груза': '820'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '382',
#   'Расход бензина': '67',
#   'Масса груза': '890'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '237',
#   'Расход бензина': '33',
#   'Масса груза': '700'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '179',
#   'Расход бензина': '25',
#   'Масса груза': '850'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '428',
#   'Расход бензина': '60',
#   'Масса груза': '900'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '135',
#   'Расход бензина': '19',
#   'Масса груза': '720'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '382',
#   'Расход бензина': '48',
#   'Масса груза': '660'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '390',
#   'Расход бензина': '54',
#   'Масса груза': '900'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '177',
#   'Расход бензина': '18',
#   'Масса груза': '990'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '295',
#   'Расход бензина': '46',
#   'Масса груза': '770'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '119',
#   'Расход бензина': '17',
#   'Масса груза': '710'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '317',
#   'Расход бензина': '44',
#   'Масса груза': '810'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '136',
#   'Расход бензина': '16',
#   'Масса груза': '580'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '387',
#   'Расход бензина': '47',
#   'Масса груза': '880'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '261',
#   'Расход бензина': '36',
#   'Масса груза': '980'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '185',
#   'Расход бензина': '26',
#   'Масса груза': '980'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '143',
#   'Расход бензина': '20',
#   'Масса груза': '520'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '111',
#   'Расход бензина': '15',
#   'Масса груза': '900'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '183',
#   'Расход бензина': '26',
#   'Масса груза': '570'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '335',
#   'Расход бензина': '51',
#   'Масса груза': '840'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '114',
#   'Расход бензина': '16',
#   'Масса груза': '790'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '388',
#   'Расход бензина': '54',
#   'Масса груза': '540'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '121',
#   'Расход бензина': '19',
#   'Масса груза': '520'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '330',
#   'Расход бензина': '46',
#   'Масса груза': '970'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '123',
#   'Расход бензина': '15',
#   'Масса груза': '540'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '315',
#   'Расход бензина': '43',
#   'Масса груза': '710'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '113',
#   'Расход бензина': '14',
#   'Масса груза': '980'},
#  {'Дата': '6 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '259',
#   'Расход бензина': '36',
#   'Масса груза': '730'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '297',
#   'Расход бензина': '31',
#   'Масса груза': '970'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '392',
#   'Расход бензина': '55',
#   'Масса груза': '540'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '435',
#   'Расход бензина': '61',
#   'Масса груза': '990'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '183',
#   'Расход бензина': '27',
#   'Масса груза': '750'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '246',
#   'Расход бензина': '36',
#   'Масса груза': '590'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '250',
#   'Расход бензина': '32',
#   'Масса груза': '970'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '186',
#   'Расход бензина': '29',
#   'Масса груза': '970'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '296',
#   'Расход бензина': '41',
#   'Масса груза': '850'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '260',
#   'Расход бензина': '36',
#   'Масса груза': '580'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '337',
#   'Расход бензина': '47',
#   'Масса груза': '600'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '186',
#   'Расход бензина': '21',
#   'Масса груза': '680'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '141',
#   'Расход бензина': '15',
#   'Масса груза': '890'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '177',
#   'Расход бензина': '24',
#   'Масса груза': '550'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '300',
#   'Расход бензина': '43',
#   'Масса груза': '500'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '384',
#   'Расход бензина': '53',
#   'Масса груза': '780'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '266',
#   'Расход бензина': '46',
#   'Масса груза': '510'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '298',
#   'Расход бензина': '41',
#   'Масса груза': '630'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '145',
#   'Расход бензина': '19',
#   'Масса груза': '950'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '310',
#   'Расход бензина': '44',
#   'Масса груза': '730'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '136',
#   'Расход бензина': '20',
#   'Масса груза': '570'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '232',
#   'Расход бензина': '32',
#   'Масса груза': '640'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '177',
#   'Расход бензина': '30',
#   'Масса груза': '640'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '190',
#   'Расход бензина': '22',
#   'Масса груза': '800'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '124',
#   'Расход бензина': '17',
#   'Масса груза': '620'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '186',
#   'Расход бензина': '25',
#   'Масса груза': '660'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '190',
#   'Расход бензина': '27',
#   'Масса груза': '760'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '386',
#   'Расход бензина': '56',
#   'Масса груза': '770'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '162',
#   'Расход бензина': '21',
#   'Масса груза': '980'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '329',
#   'Расход бензина': '46',
#   'Масса груза': '960'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '315',
#   'Расход бензина': '50',
#   'Масса груза': '650'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '136',
#   'Расход бензина': '17',
#   'Масса груза': '600'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '315',
#   'Расход бензина': '38',
#   'Масса груза': '620'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '337',
#   'Расход бензина': '44',
#   'Масса груза': '850'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '292',
#   'Расход бензина': '46',
#   'Масса груза': '850'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '296',
#   'Расход бензина': '41',
#   'Масса груза': '770'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '369',
#   'Расход бензина': '47',
#   'Масса груза': '890'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '366',
#   'Расход бензина': '47',
#   'Масса груза': '630'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '294',
#   'Расход бензина': '51',
#   'Масса груза': '780'},
#  {'Дата': '7 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '316',
#   'Расход бензина': '42',
#   'Масса груза': '980'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '164',
#   'Расход бензина': '25',
#   'Масса груза': '820'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '379',
#   'Расход бензина': '53',
#   'Масса груза': '650'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '195',
#   'Расход бензина': '27',
#   'Масса груза': '760'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '69',
#   'Расход бензина': '10',
#   'Масса груза': '890'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '119',
#   'Расход бензина': '17',
#   'Масса груза': '620'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '119',
#   'Расход бензина': '17',
#   'Масса груза': '990'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '70',
#   'Расход бензина': '10',
#   'Масса груза': '780'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '184',
#   'Расход бензина': '26',
#   'Масса груза': '630'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '134',
#   'Расход бензина': '19',
#   'Масса груза': '960'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '174',
#   'Расход бензина': '31',
#   'Масса груза': '530'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '313',
#   'Расход бензина': '45',
#   'Масса груза': '600'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '295',
#   'Расход бензина': '41',
#   'Масса груза': '840'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '70',
#   'Расход бензина': '8',
#   'Масса груза': '780'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '303',
#   'Расход бензина': '43',
#   'Масса груза': '780'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '306',
#   'Расход бензина': '35',
#   'Масса груза': '630'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '183',
#   'Расход бензина': '23',
#   'Масса груза': '790'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '158',
#   'Расход бензина': '20',
#   'Масса груза': '630'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '253',
#   'Расход бензина': '35',
#   'Масса груза': '710'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '183',
#   'Расход бензина': '26',
#   'Масса груза': '720'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '188',
#   'Расход бензина': '26',
#   'Масса груза': '930'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '251',
#   'Расход бензина': '35',
#   'Масса груза': '830'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '71',
#   'Расход бензина': '10',
#   'Масса груза': '510'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '71',
#   'Расход бензина': '10',
#   'Масса груза': '660'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '298',
#   'Расход бензина': '42',
#   'Масса груза': '540'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '196',
#   'Расход бензина': '27',
#   'Масса груза': '970'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '178',
#   'Расход бензина': '23',
#   'Масса груза': '530'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '186',
#   'Расход бензина': '26',
#   'Масса груза': '720'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '263',
#   'Расход бензина': '39',
#   'Масса груза': '580'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '323',
#   'Расход бензина': '52',
#   'Масса груза': '970'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '371',
#   'Расход бензина': '52',
#   'Масса груза': '790'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '185',
#   'Расход бензина': '31',
#   'Масса груза': '890'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '435',
#   'Расход бензина': '60',
#   'Масса груза': '620'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '123',
#   'Расход бензина': '17',
#   'Масса груза': '750'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '112',
#   'Расход бензина': '18',
#   'Масса груза': '830'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '380',
#   'Расход бензина': '43',
#   'Масса груза': '720'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '426',
#   'Расход бензина': '62',
#   'Масса груза': '910'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '192',
#   'Расход бензина': '34',
#   'Масса груза': '810'},
#  {'Дата': '8 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '190',
#   'Расход бензина': '27',
#   'Масса груза': '780'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '173',
#   'Расход бензина': '24',
#   'Масса груза': '800'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '242',
#   'Расход бензина': '40',
#   'Масса груза': '810'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '161',
#   'Расход бензина': '22',
#   'Масса груза': '660'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '338',
#   'Расход бензина': '47',
#   'Масса груза': '940'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '301',
#   'Расход бензина': '42',
#   'Масса груза': '990'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '164',
#   'Расход бензина': '29',
#   'Масса груза': '920'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '159',
#   'Расход бензина': '26',
#   'Масса груза': '900'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '435',
#   'Расход бензина': '61',
#   'Масса груза': '690'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '330',
#   'Расход бензина': '44',
#   'Масса груза': '790'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '185',
#   'Расход бензина': '26',
#   'Масса груза': '870'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '141',
#   'Расход бензина': '21',
#   'Масса груза': '520'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '190',
#   'Расход бензина': '30',
#   'Масса груза': '660'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '119',
#   'Расход бензина': '17',
#   'Масса груза': '880'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '333',
#   'Расход бензина': '52',
#   'Масса груза': '730'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '121',
#   'Расход бензина': '17',
#   'Масса груза': '530'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '141',
#   'Расход бензина': '20',
#   'Масса груза': '820'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '183',
#   'Расход бензина': '30',
#   'Масса груза': '520'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '158',
#   'Расход бензина': '22',
#   'Масса груза': '550'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '331',
#   'Расход бензина': '47',
#   'Масса груза': '690'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '122',
#   'Расход бензина': '21',
#   'Масса груза': '920'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '267',
#   'Расход бензина': '42',
#   'Масса груза': '520'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '178',
#   'Расход бензина': '25',
#   'Масса груза': '850'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '425',
#   'Расход бензина': '61',
#   'Масса груза': '830'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '267',
#   'Расход бензина': '37',
#   'Масса груза': '670'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Вязово',
#   'Расстояние': '332',
#   'Расход бензина': '46',
#   'Масса груза': '600'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '160',
#   'Расход бензина': '19',
#   'Масса груза': '670'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '114',
#   'Расход бензина': '16',
#   'Масса груза': '930'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '387',
#   'Расход бензина': '54',
#   'Масса груза': '840'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '232',
#   'Расход бензина': '33',
#   'Масса груза': '920'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '161',
#   'Расход бензина': '23',
#   'Масса груза': '530'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '335',
#   'Расход бензина': '46',
#   'Масса груза': '760'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Орехово',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '183',
#   'Расход бензина': '32',
#   'Масса груза': '670'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '332',
#   'Расход бензина': '45',
#   'Масса груза': '980'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '387',
#   'Расход бензина': '46',
#   'Масса груза': '770'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '291',
#   'Расход бензина': '38',
#   'Масса груза': '930'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '306',
#   'Расход бензина': '43',
#   'Масса груза': '510'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Буково',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '229',
#   'Расход бензина': '35',
#   'Масса груза': '770'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '190',
#   'Расход бензина': '27',
#   'Масса груза': '730'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Осинки',
#   'Расстояние': '307',
#   'Расход бензина': '36',
#   'Масса груза': '820'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '234',
#   'Расход бензина': '33',
#   'Масса груза': '860'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '165',
#   'Расход бензина': '23',
#   'Масса груза': '750'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Березки',
#   'Расстояние': '145',
#   'Расход бензина': '21',
#   'Масса груза': '770'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '127',
#   'Расход бензина': '18',
#   'Масса груза': '750'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '236',
#   'Расход бензина': '30',
#   'Масса груза': '750'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '300',
#   'Расход бензина': '45',
#   'Масса груза': '680'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Сосново',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '260',
#   'Расход бензина': '35',
#   'Масса груза': '500'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Липки',
#   'Пункт назначения': 'Дубки',
#   'Расстояние': '124',
#   'Расход бензина': '17',
#   'Масса груза': '660'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Березки',
#   'Пункт назначения': 'Буково',
#   'Расстояние': '133',
#   'Расход бензина': '17',
#   'Масса груза': '750'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Вязово',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '336',
#   'Расход бензина': '47',
#   'Масса груза': '750'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Орехово',
#   'Расстояние': '197',
#   'Расход бензина': '23',
#   'Масса груза': '750'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Осинки',
#   'Пункт назначения': 'Липки',
#   'Расстояние': '184',
#   'Расход бензина': '25',
#   'Масса груза': '520'},
#  {'Дата': '9 октября',
#   'Пункт отправления': 'Дубки',
#   'Пункт назначения': 'Сосново',
#   'Расстояние': '386',
#   'Расход бензина': '54',
#   'Масса груза': '940'}]

# %%
sum_dist = 0

weight_osinki = 0
count_osinki = 0

gasoline = 0

weight_berezki = 0
count_berezki = 0

for row in table:
    
    # 1. На какое суммарное расстояние были произведены перевозки с 7 по 9 октября?
    if '7 октября' <= row['Дата'] <= '9 октября':
        sum_dist += int(row['Расстояние'])

    # 2. Какова средняя масса груза при автоперевозках, осуществлённых из города Осинки? 
    if row['Пункт отправления'] == 'Осинки':
        weight_osinki += int(row['Масса груза'])
        count_osinki += 1
        
    # 3. Какой суммарный расход бензина был при осуществлении перевозок с 1 по 3 октября? 
    if '1 октября' <= row['Дата'] <= '3 октября':
        gasoline += int(row['Расход бензина'])
        
    # 4. Какова средняя масса груза при автоперевозках, осуществлённых в город Березки? 
    if row['Пункт назначения'] == 'Березки':
        weight_berezki += int(row['Масса груза'])
        count_berezki += 1

# %%
print(f"1. Суммарная масса груза перевозок с 7 по 9 октября: {sum_dist}")
print(f"2. Cредняя масса груза при автоперевозках, осуществлённых из города Осинки: {weight_osinki/count_osinki}")
print(f"3. Суммарный расход бензина при перевозках с 1 по 3 октября: {gasoline}")
print(f"4. Средняя масса груза при автоперевозках, осуществлённых в город Березки: {weight_berezki/count_berezki}")
# Out:
# 1. Суммарная масса груза перевозок с 7 по 9 октября: 30584
# 2. Cредняя масса груза при автоперевозках, осуществлённых из города Осинки: 732.3255813953489
# 3. Суммарный расход бензина при перевозках с 1 по 3 октября: 4027
# 4. Средняя масса груза при автоперевозках, осуществлённых в город Березки: 779.4
